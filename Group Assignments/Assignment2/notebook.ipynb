# %%
import pandas as pd

# %%
df = pd.read_csv('data/LAstats.csv')

# %%
df.shape
# Out:
# (2346, 121)

# %%
df.head()
# Out:
#      Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  6037101110  14000US06037101110  Census Tract 1011.10
# 1  6037101122  14000US06037101122  Census Tract 1011.22
# 2  6037101210  14000US06037101210  Census Tract 1012.10
# 3  6037101220  14000US06037101220  Census Tract 1012.20
# 4  6037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  SE_A10054B_004  \
# 0            0      ACSSF          3870     NaN  ...             272
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.sample()
# Out:
#         Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 1861  6037572302  14000US06037572302  Census Tract 5723.02
#
#                                               Geo_QName Geo_STUSAB  \
# 1861  Census Tract 5723.02, Los Angeles County, Cali...         ca
#
#       Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 1861         140            0      ACSSF          5731     NaN         NaN
#
#       Geo_DIVISION  Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  \
# 1861           NaN          NaN          6          37         NaN        NaN
#
#       Geo_PLACESE  Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  \
# 1861          NaN     572302         NaN         NaN         NaN
#
#       Geo_AIANHHFP  Geo_AIHHTLI  Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  \
# 1861           NaN          NaN         NaN       NaN       NaN       NaN
#
#       Geo_CSA  Geo_METDIV  Geo_MACC  Geo_MEMI  Geo_NECTA  Geo_CNECTA  \
# ...

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 121 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Geo_FIPS            2346 non-null   int64
#  1   Geo_GEOID           2346 non-null   object
#  2   Geo_NAME            2346 non-null   object
#  3   Geo_QName           2346 non-null   object
#  4   Geo_STUSAB          2346 non-null   object
#  5   Geo_SUMLEV          2346 non-null   int64
#  6   Geo_GEOCOMP         2346 non-null   int64
#  7   Geo_FILEID          2346 non-null   object
#  8   Geo_LOGRECNO        2346 non-null   int64
#  9   Geo_US              0 non-null      float64
#  10  Geo_REGION          0 non-null      float64
#  11  Geo_DIVISION        0 non-null      float64
#  12  Geo_STATECE         0 non-null      float64
#  13  Geo_STATE           2346 non-null   int64
#  14  Geo_COUNTY          2346 non-null   int64
# ...

# %%
df.Geo_FIPS.head()
# Out:
# 0    6037101110
# 1    6037101122
# 2    6037101210
# 3    6037101220
# 4    6037101300
# Name: Geo_FIPS, dtype: int64

# %%
df.Geo_STATE.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: Geo_STATE, dtype: int64

# %%
df.Geo_COUNTY.head()
# Out:
# 0    37
# 1    37
# 2    37
# 3    37
# 4    37
# Name: Geo_COUNTY, dtype: int64

# %%
df = pd.read_csv(
    'data/LAstats.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
df.head()
# Out:
#       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  06037101110  14000US06037101110  Census Tract 1011.10
# 1  06037101122  14000US06037101122  Census Tract 1011.22
# 2  06037101210  14000US06037101210  Census Tract 1012.10
# 3  06037101220  14000US06037101220  Census Tract 1012.20
# 4  06037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0            0      ACSSF          3870     NaN         NaN           NaN
# ...

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 121 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Geo_FIPS            2346 non-null   object
#  1   Geo_GEOID           2346 non-null   object
#  2   Geo_NAME            2346 non-null   object
#  3   Geo_QName           2346 non-null   object
#  4   Geo_STUSAB          2346 non-null   object
#  5   Geo_SUMLEV          2346 non-null   int64
#  6   Geo_GEOCOMP         2346 non-null   int64
#  7   Geo_FILEID          2346 non-null   object
#  8   Geo_LOGRECNO        2346 non-null   int64
#  9   Geo_US              0 non-null      float64
#  10  Geo_REGION          0 non-null      float64
#  11  Geo_DIVISION        0 non-null      float64
#  12  Geo_STATECE         0 non-null      float64
#  13  Geo_STATE           2346 non-null   object
#  14  Geo_COUNTY          2346 non-null   object
# ...

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PUMA5',
#  'Geo_PUMA1']

# %%
df = df.dropna(axis=1,how="all")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 78 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Geo_FIPS            2346 non-null   object
#  1   Geo_GEOID           2346 non-null   object
#  2   Geo_NAME            2346 non-null   object
#  3   Geo_QName           2346 non-null   object
#  4   Geo_STUSAB          2346 non-null   object
#  5   Geo_SUMLEV          2346 non-null   int64
#  6   Geo_GEOCOMP         2346 non-null   int64
#  7   Geo_FILEID          2346 non-null   object
#  8   Geo_LOGRECNO        2346 non-null   int64
#  9   Geo_STATE           2346 non-null   object
#  10  Geo_COUNTY          2346 non-null   object
#  11  Geo_TRACT           2346 non-null   int64
#  12  SE_A00002_001       2346 non-null   int64
#  13  SE_A00002_002       2343 non-null   float64
#  14  SE_A00002_003       2346 non-null   float64
# ...

# %%
df.head()
# Out:
#       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  06037101110  14000US06037101110  Census Tract 1011.10
# 1  06037101122  14000US06037101122  Census Tract 1011.22
# 2  06037101210  14000US06037101210  Census Tract 1012.10
# 3  06037101220  14000US06037101220  Census Tract 1012.20
# 4  06037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO Geo_STATE Geo_COUNTY  Geo_TRACT  \
# 0            0      ACSSF          3870        06        037     101110
# ...

# %%
columns_to_drop = ['Geo_GEOID','Geo_STUSAB','Geo_SUMLEV','Geo_GEOCOMP','Geo_FILEID','Geo_LOGRECNO']

# %%
df = df.drop(columns_to_drop,axis=1)
df.head()
# Out:
#       Geo_FIPS              Geo_NAME  \
# 0  06037101110  Census Tract 1011.10
# 1  06037101122  Census Tract 1011.22
# 2  06037101210  Census Tract 1012.10
# 3  06037101220  Census Tract 1012.20
# 4  06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STATE Geo_COUNTY  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...        06        037
# 1  Census Tract 1011.22, Los Angeles County, Cali...        06        037
# 2  Census Tract 1012.10, Los Angeles County, Cali...        06        037
# 3  Census Tract 1012.20, Los Angeles County, Cali...        06        037
# 4  Census Tract 1013, Los Angeles County, California        06        037
#
#    Geo_TRACT  SE_A00002_001  SE_A00002_002  SE_A00002_003  SE_A03001_001  \
# 0     101110           4314       9780.452       0.441084           4314
# 1     101122           3239       3172.779       1.020872           3239
# ...

# %%
columns = list(df)

# %%
columns
# Out:
# ['Geo_FIPS',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STATE',
#  'Geo_COUNTY',
#  'Geo_TRACT',
#  'SE_A00002_001',
#  'SE_A00002_002',
#  'SE_A00002_003',
#  'SE_A03001_001',
#  'SE_A03001_002',
#  'SE_A03001_003',
#  'SE_A03001_004',
#  'SE_A03001_005',
#  'SE_A03001_006',
#  'SE_A03001_007',
#  'SE_A03001_008',
#  'PCT_SE_A03001_002',
#  'PCT_SE_A03001_003',
#  'PCT_SE_A03001_004',
#  'PCT_SE_A03001_005',
#  'PCT_SE_A03001_006',
#  'PCT_SE_A03001_007',
#  'PCT_SE_A03001_008',
#  'SE_A09005_001',
#  'SE_A09005_002',
#  'SE_A09005_009',
#  'SE_A09005_010',
#  'SE_A09005_003',
#  'SE_A09005_004',
#  'SE_A09005_005',
#  'SE_A09005_006',
#  'SE_A09005_007',
#  'SE_A09005_008',
#  'PCT_SE_A09005_002',
#  'PCT_SE_A09005_009',
#  'PCT_SE_A09005_010',
#  'PCT_SE_A09005_003',
#  'PCT_SE_A09005_004',
#  'PCT_SE_A09005_005',
#  'PCT_SE_A09005_006',
#  'PCT_SE_A09005_007',
#  'PCT_SE_A09005_008',
#  'SE_A09004B_008',
#  'SE_A09004B_001',
#  'SE_A09004B_002',
#  'SE_A09004B_003',
# ...

# %%
df.columns = ['Geo_FIPS',
 'Geo_NAME',
 'Geo_QName',
 'Geo_STATE',
 'Geo_COUNTY',
 'Geo_TRACT',
 'Totalpop',
 'Popdensity',
 'Area',
 'Totalpoprace',
 'White',
 'Black',
 'AmericanIndian',
 'Asian',
 'Hw_Pacific',
 'Other',
 'Two_or_more',
 'PCT_white',
 'PCT_black',
 'PCT_americanindian',
 'PCT_asian',
 'PCT_hw_pacific',
 'PCT_other',
 'PCT_two_or_more',
 'SE_A09005_001',
 'SE_A09005_002',
 'SE_A09005_009',
 'SE_A09005_010',
 'SE_A09005_003',
 'SE_A09005_004',
 'SE_A09005_005',
 'SE_A09005_006',
 'SE_A09005_007',
 'SE_A09005_008',
 'PCT_SE_A09005_002',
 'PCT_SE_A09005_009',
 'PCT_SE_A09005_010',
 'PCT_SE_A09005_003',
 'PCT_SE_A09005_004',
 'PCT_SE_A09005_005',
 'PCT_SE_A09005_006',
 'PCT_SE_A09005_007',
 'PCT_SE_A09005_008',
 'SE_A09004B_008',
 'SE_A09004B_001',
 'SE_A09004B_002',
 'SE_A09004B_003',
 'SE_A09004B_004',
 'SE_A09004B_005',
 'SE_A09004B_006',
 'SE_A09004B_007',
 'PCT_SE_A09004B_001',
 'PCT_SE_A09004B_002',
 'PCT_SE_A09004B_003',
 'PCT_SE_A09004B_004',
 'PCT_SE_A09004B_005',
 'PCT_SE_A09004B_006',
 'PCT_SE_A09004B_007',
 'SE_A09003_001',
 'SE_A10054B_001',
 'SE_A10054B_002',
 'SE_1vehicle',
 'SE_2vehciles',
 'SE_3vehicles',
 'SE_4vehicles',
 'SE_5vehmore',
 'PCT_noveh',
 'PCT_1veh',
 'PCT_2veh',
 'PCT_3veh',
 'PCT_4veh',
 'PCT_5vehmore']

# %%
df.head()
# Out:
#       Geo_FIPS              Geo_NAME  \
# 0  06037101110  Census Tract 1011.10
# 1  06037101122  Census Tract 1011.22
# 2  06037101210  Census Tract 1012.10
# 3  06037101220  Census Tract 1012.20
# 4  06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STATE Geo_COUNTY  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...        06        037
# 1  Census Tract 1011.22, Los Angeles County, Cali...        06        037
# 2  Census Tract 1012.10, Los Angeles County, Cali...        06        037
# 3  Census Tract 1012.20, Los Angeles County, Cali...        06        037
# 4  Census Tract 1013, Los Angeles County, California        06        037
#
#    Geo_TRACT  Totalpop  Popdensity      Area  Totalpoprace  White  Black  \
# 0     101110      4314    9780.452  0.441084          4314   3314     47
# 1     101122      3239    3172.779  1.020872          3239   2837     61
# ...

# %%
columns_to_drop = ['SE_A09005_001',
 'SE_A09005_002',
 'SE_A09005_009',
 'SE_A09005_010',
 'SE_A09005_003',
 'SE_A09005_004',
 'SE_A09005_005',
 'SE_A09005_006',
 'SE_A09005_007',
 'SE_A09005_008',
 'PCT_SE_A09005_002',
 'PCT_SE_A09005_009',
 'PCT_SE_A09005_010',
 'PCT_SE_A09005_003',
 'PCT_SE_A09005_004',
 'PCT_SE_A09005_005',
 'PCT_SE_A09005_006',
 'PCT_SE_A09005_007',
 'PCT_SE_A09005_008',
 'SE_A09004B_008',
 'SE_A09004B_001',
 'SE_A09004B_002',
 'SE_A09004B_003',
 'SE_A09004B_004',
 'SE_A09004B_005',
 'SE_A09004B_006',
 'SE_A09004B_007',
 'PCT_SE_A09004B_001',
 'PCT_SE_A09004B_002',
 'PCT_SE_A09004B_003',
 'PCT_SE_A09004B_004',
 'PCT_SE_A09004B_005',
 'PCT_SE_A09004B_006',
 'PCT_SE_A09004B_007',
 'SE_A09003_001',
 'SE_A10054B_001',
 'SE_A10054B_002',
 'SE_A10054B_002',
 'SE_1vehicle',
 'SE_2vehciles',
 'SE_3vehicles',
 'SE_4vehicles',
 'SE_5vehmore',
 'PCT_noveh',
 'PCT_1veh',
 'PCT_2veh',
 'PCT_3veh',
 'PCT_4veh',
 'PCT_5vehmore']

# %%
df = df.drop(columns_to_drop,axis=1)
df.head()
# Out:
#       Geo_FIPS              Geo_NAME  \
# 0  06037101110  Census Tract 1011.10
# 1  06037101122  Census Tract 1011.22
# 2  06037101210  Census Tract 1012.10
# 3  06037101220  Census Tract 1012.20
# 4  06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STATE Geo_COUNTY  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...        06        037
# 1  Census Tract 1011.22, Los Angeles County, Cali...        06        037
# 2  Census Tract 1012.10, Los Angeles County, Cali...        06        037
# 3  Census Tract 1012.20, Los Angeles County, Cali...        06        037
# 4  Census Tract 1013, Los Angeles County, California        06        037
#
#    Geo_TRACT  Totalpop  Popdensity      Area  Totalpoprace  White  Black  \
# 0     101110      4314    9780.452  0.441084          4314   3314     47
# 1     101122      3239    3172.779  1.020872          3239   2837     61
# ...

# %%
df['Totalpop'].mean()
# Out:
# 4304.36999147485

# %%
df['Totalpop'].plot.hist(bins=50)

# %%
len(df)
# Out:
# 2346

# %%
df.isna().sum()
# Out:
# Geo_FIPS               0
# Geo_NAME               0
# Geo_QName              0
# Geo_STATE              0
# Geo_COUNTY             0
# Geo_TRACT              0
# Totalpop               0
# Popdensity             3
# Area                   0
# Totalpoprace           0
# White                  0
# Black                  0
# AmericanIndian         0
# Asian                  0
# Hw_Pacific             0
# Other                  0
# Two_or_more            0
# PCT_white             19
# PCT_black             19
# PCT_americanindian    19
# PCT_asian             19
# PCT_hw_pacific        19
# PCT_other             19
# PCT_two_or_more       19
# dtype: int64

# %%
df[df['PCT_black'].isnull()]
# Out:
#          Geo_FIPS              Geo_NAME  \
# 1054  06037320000     Census Tract 3200
# 2317  06037980001  Census Tract 9800.01
# 2318  06037980002  Census Tract 9800.02
# 2319  06037980003  Census Tract 9800.03
# 2320  06037980004  Census Tract 9800.04
# 2321  06037980005  Census Tract 9800.05
# 2322  06037980006  Census Tract 9800.06
# 2323  06037980007  Census Tract 9800.07
# 2327  06037980013  Census Tract 9800.13
# 2330  06037980018  Census Tract 9800.18
# 2332  06037980020  Census Tract 9800.20
# 2334  06037980022  Census Tract 9800.22
# 2335  06037980023  Census Tract 9800.23
# 2337  06037980025  Census Tract 9800.25
# 2339  06037980028  Census Tract 9800.28
# 2340  06037980030  Census Tract 9800.30
# 2343  06037990100     Census Tract 9901
# 2344  06037990200     Census Tract 9902
# 2345  06037990300     Census Tract 9903
#
#                                               Geo_QName Geo_STATE Geo_COUNTY  \
# ...

# %%
df_sorted = df.sort_values(by='Popdensity',ascending = False)

# %%
df_sorted[['Geo_NAME','Popdensity']].head(10)
# Out:
#                  Geo_NAME  Popdensity
# 595  Census Tract 2119.22    98198.34
# 565  Census Tract 2091.04    97367.97
# 562  Census Tract 2089.04    95046.70
# 848  Census Tract 2653.03    85556.52
# 133  Census Tract 1193.40    85492.57
# 593  Census Tract 2119.10    82656.00
# 564  Census Tract 2091.03    77439.63
# 569  Census Tract 2094.02    74999.10
# 603  Census Tract 2123.05    74925.52
# 599  Census Tract 2122.03    72547.73

# %%
df_sorted.head(10).plot.bar(x='Geo_NAME',
                            y='Popdensity')

# %%
df_sorted.head(10).plot.bar(x='Geo_NAME',
                            y='Popdensity', 
                            title='Top 10 Census Tracts with Highest Population Density in Los Angeles County')

# %%
df_sorted.head(10).plot.bar(x='Geo_NAME',
                           y='Two_or_more',
                           title='Top 10 Census Tracts with Highest Two or More Races in LA County')

# %%
df_50black = df[df['PCT_black'] >= 50].sort_values(by='PCT_black',ascending = False)
df_50black[['Geo_NAME','PCT_black']]
# Out:
#                   Geo_NAME  PCT_black
# 1956  Census Tract 6008.02      83.92
# 1701  Census Tract 5433.04      83.72
# 1954  Census Tract 6007.04      83.03
# 1953  Census Tract 6007.03      82.92
# 2150     Census Tract 7032      82.91
# 1950  Census Tract 6006.01      82.15
# 764      Census Tract 2364      81.06
# 748      Census Tract 2343      79.90
# 1955  Census Tract 6008.01      78.57
# 783      Census Tract 2384      78.34
# 2149     Census Tract 7031      77.47
# 1947     Census Tract 6004      76.16
# 1952  Census Tract 6007.02      75.28
# 780      Census Tract 2382      73.11
# 2148  Census Tract 7030.02      72.69
# 1705  Census Tract 5433.22      72.57
# 779      Census Tract 2381      71.71
# 1998     Census Tract 6027      70.67
# 777      Census Tract 2379      69.94
# 1944  Census Tract 6003.02      69.87
# 747      Census Tract 2342      69.38
# 778      Census Tract 2380      69.05
# 1948  Census Tract 6005.01      68.47
# 756      Census Tract 2351      68.17
# ...

# %%
import geopandas as gpd

# %%
tracts=gpd.read_file('../../data/la_tracts.geojson')
tracts.head()
# Out:
#                   kind  external_id         name  \
# 0  Census Tract (2012)  06037101110  06037101110
# 1  Census Tract (2012)  06037101122  06037101122
# 2  Census Tract (2012)  06037101210  06037101210
# 3  Census Tract (2012)  06037101220  06037101220
# 4  Census Tract (2012)  06037101300  06037101300
#
#                             slug                                    set  \
# 0  06037101110-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 1  06037101122-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2  06037101210-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 3  06037101220-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 4  06037101300-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
#
#                                             metadata  \
# 0  {'INTPTLAT': '+34.2594737', 'NAME': '1011.10',...
# 1  {'INTPTLAT': '+34.2677213', 'NAME': '1011.22',...
# 2  {'INTPTLAT': '+34.2529724', 'NAME': '1012.10',...
# ...

# %%
tracts.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kind          2346 non-null   object
#  1   external_id   2346 non-null   object
#  2   name          2346 non-null   object
#  3   slug          2346 non-null   object
#  4   set           2346 non-null   object
#  5   metadata      2346 non-null   object
#  6   resource_uri  2346 non-null   object
#  7   geometry      2346 non-null   geometry
# dtypes: geometry(1), object(7)
# memory usage: 146.8+ KB

# %%
tracts = tracts[['name','geometry']]
tracts.head()
# Out:
#           name                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
tracts.columns = ['Geo_FIPS','geometry']

# %%
tracts.head()
# Out:
#       Geo_FIPS                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
tracts.plot(figsize=(12,10))

# %%
columns
# Out:
# ['Geo_FIPS',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STATE',
#  'Geo_COUNTY',
#  'Geo_TRACT',
#  'SE_A00002_001',
#  'SE_A00002_002',
#  'SE_A00002_003',
#  'SE_A03001_001',
#  'SE_A03001_002',
#  'SE_A03001_003',
#  'SE_A03001_004',
#  'SE_A03001_005',
#  'SE_A03001_006',
#  'SE_A03001_007',
#  'SE_A03001_008',
#  'PCT_SE_A03001_002',
#  'PCT_SE_A03001_003',
#  'PCT_SE_A03001_004',
#  'PCT_SE_A03001_005',
#  'PCT_SE_A03001_006',
#  'PCT_SE_A03001_007',
#  'PCT_SE_A03001_008',
#  'SE_A09005_001',
#  'SE_A09005_002',
#  'SE_A09005_009',
#  'SE_A09005_010',
#  'SE_A09005_003',
#  'SE_A09005_004',
#  'SE_A09005_005',
#  'SE_A09005_006',
#  'SE_A09005_007',
#  'SE_A09005_008',
#  'PCT_SE_A09005_002',
#  'PCT_SE_A09005_009',
#  'PCT_SE_A09005_010',
#  'PCT_SE_A09005_003',
#  'PCT_SE_A09005_004',
#  'PCT_SE_A09005_005',
#  'PCT_SE_A09005_006',
#  'PCT_SE_A09005_007',
#  'PCT_SE_A09005_008',
#  'SE_A09004B_008',
#  'SE_A09004B_001',
#  'SE_A09004B_002',
#  'SE_A09004B_003',
# ...

# %%
tracts_race=tracts.merge(df,on="Geo_FIPS")

# %%
tracts_race.head()
# Out:
#       Geo_FIPS                                           geometry  \
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...
#
#                Geo_NAME                                          Geo_QName  \
# 0  Census Tract 1011.10  Census Tract 1011.10, Los Angeles County, Cali...
# 1  Census Tract 1011.22  Census Tract 1011.22, Los Angeles County, Cali...
# 2  Census Tract 1012.10  Census Tract 1012.10, Los Angeles County, Cali...
# 3  Census Tract 1012.20  Census Tract 1012.20, Los Angeles County, Cali...
# 4     Census Tract 1013  Census Tract 1013, Los Angeles County, California
#
#   Geo_STATE Geo_COUNTY  Geo_TRACT  Totalpop  Popdensity      Area  \
# ...

# %%
tracts_race.plot(figsize=(12,10),
                 column='Popdensity',
                 legend=True, 
                 scheme='NaturalBreaks')

# %%
tracts_race.plot(figsize=(12,10),
                 column='Popdensity',
                 legend=True, 
                 scheme='equal_interval')

# %%
tracts_race[tracts_race.PCT_white > 50].plot(figsize=(12,10),
                                             column='PCT_white',
                                             legend=True, 
                                             scheme='NaturalBreaks')

# %%
tracts_race[tracts_race.PCT_black > 50].plot(figsize=(12,10),
                                             column='PCT_black',
                                             legend=True, 
                                             scheme='NaturalBreaks')

# %%
tracts_race[tracts_race.PCT_asian > 50].plot(figsize=(12,10),
                                             column='PCT_asian',
                                             legend=True, 
                                             scheme='NaturalBreaks')

# %%
tracts_race[tracts_race.PCT_americanindian > 50].plot(figsize=(12,10),
                                             column='PCT_americanindian',
                                             legend=True, 
                                             scheme='NaturalBreaks')
# Out:
# /opt/conda/lib/python3.8/site-packages/mapclassify/classifiers.py:1712: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(ms, UserWarning)
# /opt/conda/lib/python3.8/site-packages/mapclassify/classifiers.py:1713: UserWarning: Warning: setting k to 1
#   Warn("Warning: setting k to %d" % uvk, UserWarning)
# /opt/conda/lib/python3.8/site-packages/mapclassify/classifiers.py:888: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 - self.adcm / adam

# %%
tracts_race[tracts_race.PCT_other > 50].plot(figsize=(12,10),
                                             column='PCT_other',
                                             legend=True, 
                                             scheme='NaturalBreaks')

# %%
tracts_race[tracts_race.PCT_two_or_more > 50].plot(figsize=(12,10),
                                             column='PCT_two_or_more',
                                             legend=True, 
                                             scheme='NaturalBreaks')
# Out:
# /opt/conda/lib/python3.8/site-packages/mapclassify/classifiers.py:1712: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(ms, UserWarning)
# /opt/conda/lib/python3.8/site-packages/mapclassify/classifiers.py:1713: UserWarning: Warning: setting k to 1
#   Warn("Warning: setting k to %d" % uvk, UserWarning)
# /opt/conda/lib/python3.8/site-packages/mapclassify/classifiers.py:888: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 - self.adcm / adam

# %%
tracts_race.plot(figsize=(12,10),
                 column='PCT_two_or_more',
                 legend=True, 
                 scheme='equal_interval')
